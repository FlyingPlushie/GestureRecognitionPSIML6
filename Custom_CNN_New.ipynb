# %%
import time
import os
import copy
from collections import defaultdict

# deep learning/vision libraries
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
from torchvision import datasets, models, transforms
import cv2 as cv  # OpenCV

# numeric and plotting libraries
import numpy as np
import matplotlib.pyplot as plt
from kard_data_loader import KardDataLoader
import consts as c

# %%
train = KardDataLoader('C:\\Users\\bozam\\Desktop\\KARD train test validation\\train\\')
train.getActivityData(c.FILETYPES['screen'])

# %%
test = KardDataLoader('C:\\Users\\bozam\\Desktop\\KARD train test validation\\test\\')
test.getActivityData(c.FILETYPES['screen'])

# %%
validation = KardDataLoader('C:\\Users\\bozam\\Desktop\\KARD train test validation\\validation\\')
validation.getActivityData(c.FILETYPES['screen'])

# %%
def normalize(arr):
    return (arr - np.min(arr)) / (np.max(arr) - np.min(arr))

# %%
def make_training_set(data):
    generated_images = []
    generated_classes = []
    x = []
    y = []
    z = []
            
    for class_name in range(len(data)):
        image_sequence = []
        for people_sequences in range(len(data[class_name])):
            counter = 0
            for people_coordinates in data[class_name][people_sequences]:
                x.append(people_coordinates[0])
                y.append(people_coordinates[1])
                z.append(people_coordinates[2])
                counter += 1
                
                if counter == 15:
                    counter = 0
                    x = normalize(x)
                    
                    y = normalize(y)
                    
                    z = normalize(z)
                    
                    image_layer = [[x[i], y[i], z[i]] for i in range(15)]
                    generated_images.append(image_layer)
                    generated_classes.append(class_name)
                    x = []
                    y = []
                    z = []
            
    return generated_images, generated_classes

# %%
train_images, train_labels = make_training_set(train.data)
train_images = np.array(train_images)
train_labels = np.array(train_labels)

# %%
validation_images, validation_labels = make_training_set(validation.data)
validation_images = np.array(validation_images)
validation_labels = np.array(validation_labels)

# %%
test_images, test_labels = make_training_set(test.data)
test_images = np.array(test_images)
test_labels = np.array(test_labels)

# %%
def to_categorical(y, num_classes):
    return np.eye(num_classes, dtype='uint8')[y]

# %%
def make_images_compact(train_data, train_labels, batch_size, stride):
    batch_edges = [[a, a + batch_size] for a in range(0 , len(train_data) - batch_size, stride) if train_labels[a] == train_labels[a + batch_size]]
    
    batch_data = []
    batch_labels = []
    
    for (a, b) in (batch_edges):
        batch_data.append(train_data[a:b])
        batch_labels.append(train_labels[a])
    
    rnd_idx = np.random.permutation(len(batch_data))
    batch_data = np.array(batch_data)
    batch_labels = np.array(batch_labels)
    
    batch_data = batch_data[rnd_idx, :, :, :]
    batch_labels = batch_labels[rnd_idx]
    
    return (batch_data, batch_labels)

# %%
def make_batches(X_train, y_train, batch_size):
    n_batches = len(X_train) // batch_size
    indexes = np.array(list(range(0, len(X_train))))
    for batch_idx in np.array_split(indexes, n_batches):
        X_batch, y_batch = X_train[batch_idx], y_train[batch_idx]
        yield X_batch, y_batch

# %%
train_images_new, train_labels_new = make_images_compact(train_images, train_labels, 40, 3)

# %%
validation_images_new, validation_labels_new = make_images_compact(validation_images, validation_labels, 40, 3)

# %%
test_images_new, test_labels_new = make_images_compact(test_images, test_labels, 40, 3)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %%
def train_model(model, criterion, optimizer, num_epochs=100):
    
    metrics = defaultdict(list)
    best_acc = 0
    
    for epoch in range(num_epochs):
        print(f'Epoch {epoch}/{num_epochs - 1}')
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', "val"]:
            if phase == 'train':
                model.train()  # Set model to training mode
                data = train_images_new
                labels = train_labels_new
            else:
                model.eval()   # Set model to evaluate mode
                data = validation_images_new
                labels = validation_labels_new
                
            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            # 40, 15, 3 - > 3, 15, 40
            #print(np.array(train_images).shape)
            #print(np.array(train_labels).shape)
            for (inputs, labels) in make_batches(data, labels, 40):
                #print(np.array(inputs).shape)
                #inputs = inputs.reshape(3, 15, 41)
                inputs = inputs.reshape(-1, 3, 15, 40)
                inputs = torch.from_numpy(inputs)
                labels = torch.from_numpy(np.array([labels]))
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()
                
                # forward
                # track history if only in train
                #print("Pre setovanja gradienata!")
                with torch.set_grad_enabled(phase == 'train'):
                    #print("Ulazim u setovanje gradienata!!!!")
                    outputs = model(inputs.float())
                    
                    _, preds = torch.max(outputs, 1)
                    labels = labels.view(-1)
                    loss = criterion(outputs, labels.long())
                    #print(loss)
                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data).item()
            
            epoch_loss = running_loss / len(data)
            epoch_acc = float(running_corrects) / len(data)

            print(f'{phase} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())
            
            metrics[phase+"_loss"].append(epoch_loss)
            metrics[phase+"_acc"].append(epoch_acc)

    return metrics

# %%
class CustomCNN(nn.Module):
    def __init__(self):
        super().__init__()
        
        num_of_channels = [3, 16, 32, 48]
        kernel_sizes = [3, 3, 3, 3]
        stride_sizes = [2, 2, 2, 2]
        
        self.relu = torch.nn.ReLU()
        
        self.conv1 = nn.Conv2d(num_of_channels[0], num_of_channels[1], kernel_size=(2, 2), stride=stride_sizes[0])
        self.bn1 = nn.BatchNorm2d(num_of_channels[1])
        self.conv2 = nn.Conv2d(num_of_channels[1], num_of_channels[2], kernel_size=(2, 2), stride=stride_sizes[1])
        self.bn2 = nn.BatchNorm2d(num_of_channels[2])
        self.conv3 = nn.Conv2d(num_of_channels[2], num_of_channels[3], kernel_size=(2, 2), stride=stride_sizes[2])
        self.bn3 = nn.BatchNorm2d(num_of_channels[3])
        #self.conv4 = nn.Conv2d(num_of_channels[3], num_of_channels[4], kernel_size=(2, 3), stride=stride_sizes[3])
        self.avgpool = nn.AdaptiveAvgPool2d((7, 7))
        self.classifier = nn.Linear(num_of_channels[-1] * 7 * 7, 18)
        
        
    def forward(self, x):
        y = self.relu(self.conv1(x))
        y = self.bn1(y)
        y = self.relu(self.conv2(y))
        y = self.bn2(y)
        y = self.relu(self.conv3(y))
        y = self.bn3(y)
       # y = self.relu(self.conv4(y))
        y = self.avgpool(y)
        y = torch.flatten(y, 1)
        y = self.classifier(y)
        
        return y
    
    
custom_cnn = CustomCNN().to(device)
optimizer_conv = optim.SGD(filter(lambda p: p.requires_grad, custom_cnn.parameters()), lr = 0.0001)

print(f"number of params in model {count_parameters(custom_cnn)}")

criterion = nn.CrossEntropyLoss()
metrics = train_model(custom_cnn, criterion, optimizer_conv, num_epochs=100)
# Out:
# number of params in model 51026
# Epoch 0/99
# ----------
# train Loss: 2.7061 Acc: 0.1646
# val Loss: 2.4138 Acc: 0.3158
# Epoch 1/99
# ----------
# train Loss: 2.2858 Acc: 0.3720
# val Loss: 2.0227 Acc: 0.4372
# Epoch 2/99
# ----------
# train Loss: 2.0144 Acc: 0.4591
# val Loss: 1.7542 Acc: 0.5223
# Epoch 3/99
# ----------
# train Loss: 1.8186 Acc: 0.5124
# val Loss: 1.5613 Acc: 0.5749
# Epoch 4/99
# ----------
# train Loss: 1.6703 Acc: 0.5508
# val Loss: 1.4179 Acc: 0.6154
# Epoch 5/99
# ----------
# train Loss: 1.5550 Acc: 0.5774
# val Loss: 1.3077 Acc: 0.6356
# Epoch 6/99
# ----------
# train Loss: 1.4624 Acc: 0.5985
# val Loss: 1.2209 Acc: 0.6538
# Epoch 7/99
# ----------
# train Loss: 1.3859 Acc: 0.6152
# val Loss: 1.1500 Acc: 0.6640
# Epoch 8/99
# ----------
# train Loss: 1.3212 Acc: 0.6316
# val Loss: 1.0906 Acc: 0.6842
# Epoch 9/99
# ----------
# train Loss: 1.2655 Acc: 0.6471
# val Loss: 1.0405 Acc: 0.6923
# Epoch 10/99
# ----------
# train Loss: 1.2168 Acc: 0.6588
# val Loss: 0.9976 Acc: 0.7085
# Epoch 11/99
# ----------
# train Loss: 1.1737 Acc: 0.6693
# val Loss: 0.9597 Acc: 0.7186
# Epoch 12/99
# ----------
# train Loss: 1.1350 Acc: 0.6770
# val Loss: 0.9271 Acc: 0.7247
# Epoch 13/99
# ----------
# train Loss: 1.1001 Acc: 0.6853
# val Loss: 0.8981 Acc: 0.7328
# Epoch 14/99
# ----------
# train Loss: 1.0683 Acc: 0.6942
# val Loss: 0.8720 Acc: 0.7449
# Epoch 15/99
# ----------
# train Loss: 1.0390 Acc: 0.7026
# val Loss: 0.8488 Acc: 0.7530
# Epoch 16/99
# ----------
# train Loss: 1.0120 Acc: 0.7096
# val Loss: 0.8283 Acc: 0.7611
# Epoch 17/99
# ----------
# train Loss: 0.9870 Acc: 0.7162
# val Loss: 0.8095 Acc: 0.7652
# Epoch 18/99
# ----------
# train Loss: 0.9638 Acc: 0.7222
# val Loss: 0.7919 Acc: 0.7672
# Epoch 19/99
# ----------
# train Loss: 0.9421 Acc: 0.7276
# val Loss: 0.7758 Acc: 0.7672
# Epoch 20/99
# ----------
# train Loss: 0.9218 Acc: 0.7323
# val Loss: 0.7611 Acc: 0.7652
# Epoch 21/99
# ----------
# train Loss: 0.9026 Acc: 0.7374
# val Loss: 0.7475 Acc: 0.7672
# Epoch 22/99
# ----------
# train Loss: 0.8847 Acc: 0.7422
# val Loss: 0.7347 Acc: 0.7652
# Epoch 23/99
# ----------
# train Loss: 0.8677 Acc: 0.7469
# val Loss: 0.7228 Acc: 0.7692
# Epoch 24/99
# ----------
# train Loss: 0.8516 Acc: 0.7503
# val Loss: 0.7118 Acc: 0.7692
# Epoch 25/99
# ----------
# train Loss: 0.8363 Acc: 0.7542
# val Loss: 0.7012 Acc: 0.7753
# Epoch 26/99
# ----------
# train Loss: 0.8217 Acc: 0.7578
# val Loss: 0.6914 Acc: 0.7733
# Epoch 27/99
# ----------
# train Loss: 0.8078 Acc: 0.7618
# val Loss: 0.6825 Acc: 0.7794
# Epoch 28/99
# ----------
# train Loss: 0.7946 Acc: 0.7655
# val Loss: 0.6741 Acc: 0.7834
# Epoch 29/99
# ----------
# train Loss: 0.7819 Acc: 0.7691
# val Loss: 0.6662 Acc: 0.7895
# Epoch 30/99
# ----------
# train Loss: 0.7697 Acc: 0.7726
# val Loss: 0.6582 Acc: 0.7895
# Epoch 31/99
# ----------
# train Loss: 0.7581 Acc: 0.7766
# val Loss: 0.6505 Acc: 0.7915
# Epoch 32/99
# ----------
# train Loss: 0.7469 Acc: 0.7791
# val Loss: 0.6433 Acc: 0.7996
# Epoch 33/99
# ----------
# train Loss: 0.7361 Acc: 0.7823
# val Loss: 0.6366 Acc: 0.8077
# Epoch 34/99
# ----------
# train Loss: 0.7257 Acc: 0.7860
# val Loss: 0.6302 Acc: 0.8077
# Epoch 35/99
# ----------
# train Loss: 0.7157 Acc: 0.7895
# val Loss: 0.6244 Acc: 0.8057
# Epoch 36/99
# ----------
# train Loss: 0.7061 Acc: 0.7923
# val Loss: 0.6188 Acc: 0.8077
# Epoch 37/99
# ----------
# train Loss: 0.6968 Acc: 0.7951
# val Loss: 0.6133 Acc: 0.8117
# Epoch 38/99
# ----------
# train Loss: 0.6878 Acc: 0.7989
# val Loss: 0.6080 Acc: 0.8158
# Epoch 39/99
# ----------
# train Loss: 0.6790 Acc: 0.8008
# val Loss: 0.6027 Acc: 0.8158
# Epoch 40/99
# ----------
# train Loss: 0.6706 Acc: 0.8032
# val Loss: 0.5977 Acc: 0.8158
# Epoch 41/99
# ----------
# train Loss: 0.6624 Acc: 0.8052
# val Loss: 0.5927 Acc: 0.8158
# Epoch 42/99
# ----------
# train Loss: 0.6544 Acc: 0.8075
# val Loss: 0.5880 Acc: 0.8178
# Epoch 43/99
# ----------
# train Loss: 0.6467 Acc: 0.8096
# val Loss: 0.5836 Acc: 0.8178
# Epoch 44/99
# ----------
# train Loss: 0.6392 Acc: 0.8121
# val Loss: 0.5794 Acc: 0.8178
# Epoch 45/99
# ----------
# train Loss: 0.6318 Acc: 0.8140
# val Loss: 0.5753 Acc: 0.8198
# Epoch 46/99
# ----------
# train Loss: 0.6247 Acc: 0.8158
# val Loss: 0.5714 Acc: 0.8198
# Epoch 47/99
# ----------
# train Loss: 0.6178 Acc: 0.8181
# val Loss: 0.5674 Acc: 0.8178
# Epoch 48/99
# ----------
# train Loss: 0.6110 Acc: 0.8196
# val Loss: 0.5634 Acc: 0.8198
# Epoch 49/99
# ----------
# train Loss: 0.6044 Acc: 0.8218
# val Loss: 0.5596 Acc: 0.8219
# Epoch 50/99
# ----------
# train Loss: 0.5980 Acc: 0.8239
# val Loss: 0.5555 Acc: 0.8239
# Epoch 51/99
# ----------
# train Loss: 0.5917 Acc: 0.8259
# val Loss: 0.5522 Acc: 0.8259
# Epoch 52/99
# ----------
# train Loss: 0.5856 Acc: 0.8283
# val Loss: 0.5489 Acc: 0.8259
# Epoch 53/99
# ----------
# train Loss: 0.5796 Acc: 0.8304
# val Loss: 0.5458 Acc: 0.8259
# Epoch 54/99
# ----------
# train Loss: 0.5738 Acc: 0.8319
# val Loss: 0.5428 Acc: 0.8279
# Epoch 55/99
# ----------
# train Loss: 0.5681 Acc: 0.8338
# val Loss: 0.5399 Acc: 0.8279
# Epoch 56/99
# ----------
# train Loss: 0.5625 Acc: 0.8347
# val Loss: 0.5370 Acc: 0.8300
# Epoch 57/99
# ----------
# train Loss: 0.5571 Acc: 0.8362
# val Loss: 0.5341 Acc: 0.8300
# Epoch 58/99
# ----------
# train Loss: 0.5518 Acc: 0.8378
# val Loss: 0.5314 Acc: 0.8320
# Epoch 59/99
# ----------
# train Loss: 0.5466 Acc: 0.8399
# val Loss: 0.5287 Acc: 0.8300
# Epoch 60/99
# ----------
# train Loss: 0.5415 Acc: 0.8414
# val Loss: 0.5263 Acc: 0.8300
# Epoch 61/99
# ----------
# train Loss: 0.5365 Acc: 0.8426
# val Loss: 0.5238 Acc: 0.8300
# Epoch 62/99
# ----------
# train Loss: 0.5317 Acc: 0.8443
# val Loss: 0.5213 Acc: 0.8320
# Epoch 63/99
# ----------
# train Loss: 0.5269 Acc: 0.8457
# val Loss: 0.5189 Acc: 0.8300
# Epoch 64/99
# ----------
# train Loss: 0.5222 Acc: 0.8469
# val Loss: 0.5164 Acc: 0.8340
# Epoch 65/99
# ----------
# train Loss: 0.5177 Acc: 0.8485
# val Loss: 0.5142 Acc: 0.8340
# Epoch 66/99
# ----------
# train Loss: 0.5132 Acc: 0.8507
# val Loss: 0.5119 Acc: 0.8381
# Epoch 67/99
# ----------
# train Loss: 0.5088 Acc: 0.8524
# val Loss: 0.5097 Acc: 0.8401
# Epoch 68/99
# ----------
# train Loss: 0.5045 Acc: 0.8533
# val Loss: 0.5077 Acc: 0.8401
# Epoch 69/99
# ----------
# train Loss: 0.5002 Acc: 0.8542
# val Loss: 0.5058 Acc: 0.8421
# Epoch 70/99
# ----------
# train Loss: 0.4961 Acc: 0.8556
# val Loss: 0.5039 Acc: 0.8441
# Epoch 71/99
# ----------
# train Loss: 0.4920 Acc: 0.8571
# val Loss: 0.5020 Acc: 0.8441
# Epoch 72/99
# ----------
# train Loss: 0.4880 Acc: 0.8586
# val Loss: 0.5002 Acc: 0.8441
# Epoch 73/99
# ----------
# train Loss: 0.4840 Acc: 0.8596
# val Loss: 0.4984 Acc: 0.8421
# Epoch 74/99
# ----------
# train Loss: 0.4802 Acc: 0.8609
# val Loss: 0.4968 Acc: 0.8421
# Epoch 75/99
# ----------
# train Loss: 0.4763 Acc: 0.8620
# val Loss: 0.4951 Acc: 0.8421
# Epoch 76/99
# ----------
# train Loss: 0.4726 Acc: 0.8629
# val Loss: 0.4934 Acc: 0.8401
# Epoch 77/99
# ----------
# train Loss: 0.4689 Acc: 0.8645
# val Loss: 0.4917 Acc: 0.8421
# Epoch 78/99
# ----------
# train Loss: 0.4653 Acc: 0.8656
# val Loss: 0.4901 Acc: 0.8462
# Epoch 79/99
# ----------
# train Loss: 0.4617 Acc: 0.8665
# val Loss: 0.4884 Acc: 0.8441
# Epoch 80/99
# ----------
# train Loss: 0.4582 Acc: 0.8673
# val Loss: 0.4868 Acc: 0.8441
# Epoch 81/99
# ----------
# train Loss: 0.4548 Acc: 0.8683
# val Loss: 0.4855 Acc: 0.8441
# Epoch 82/99
# ----------
# train Loss: 0.4514 Acc: 0.8689
# val Loss: 0.4841 Acc: 0.8441
# Epoch 83/99
# ----------
# train Loss: 0.4480 Acc: 0.8703
# val Loss: 0.4829 Acc: 0.8441
# Epoch 84/99
# ----------
# train Loss: 0.4448 Acc: 0.8715
# val Loss: 0.4816 Acc: 0.8441
# Epoch 85/99
# ----------
# train Loss: 0.4415 Acc: 0.8726
# val Loss: 0.4805 Acc: 0.8421
# Epoch 86/99
# ----------
# train Loss: 0.4383 Acc: 0.8737
# val Loss: 0.4793 Acc: 0.8441
# Epoch 87/99
# ----------
# train Loss: 0.4352 Acc: 0.8747
# val Loss: 0.4783 Acc: 0.8441
# Epoch 88/99
# ----------
# train Loss: 0.4321 Acc: 0.8756
# val Loss: 0.4771 Acc: 0.8441
# Epoch 89/99
# ----------
# train Loss: 0.4291 Acc: 0.8770
# val Loss: 0.4760 Acc: 0.8441
# Epoch 90/99
# ----------
# train Loss: 0.4261 Acc: 0.8779
# val Loss: 0.4750 Acc: 0.8401
# Epoch 91/99
# ----------
# train Loss: 0.4232 Acc: 0.8787
# val Loss: 0.4741 Acc: 0.8401
# Epoch 92/99
# ----------
# train Loss: 0.4203 Acc: 0.8795
# val Loss: 0.4730 Acc: 0.8401
# Epoch 93/99
# ----------
# train Loss: 0.4174 Acc: 0.8803
# val Loss: 0.4719 Acc: 0.8421
# Epoch 94/99
# ----------
# train Loss: 0.4146 Acc: 0.8818
# val Loss: 0.4708 Acc: 0.8441
# Epoch 95/99
# ----------
# train Loss: 0.4118 Acc: 0.8823
# val Loss: 0.4697 Acc: 0.8462
# Epoch 96/99
# ----------
# train Loss: 0.4090 Acc: 0.8833
# val Loss: 0.4686 Acc: 0.8462
# Epoch 97/99
# ----------
# train Loss: 0.4063 Acc: 0.8838
# val Loss: 0.4677 Acc: 0.8462
# Epoch 98/99
# ----------
# train Loss: 0.4036 Acc: 0.8846
# val Loss: 0.4669 Acc: 0.8482
# Epoch 99/99
# ----------
# train Loss: 0.4010 Acc: 0.8855
# val Loss: 0.4660 Acc: 0.8482

# %%
plt.plot(list(range(0, len(metrics["train_loss"]))), metrics["train_loss"], label = "Train loss")
plt.plot(list(range(0, len(metrics["val_loss"]))), metrics["val_loss"], label = "Val loss")
plt.legend()
plt.title("SGD, BN, LR = 1e-4 [3, 16, 32, 48]")
plt.savefig("Images/15")

# %%
plt.plot(list(range(0, len(metrics["train_acc"]))), metrics["train_acc"], label = "Train accuracy")
plt.plot(list(range(0, len(metrics["val_acc"]))), metrics["val_acc"], label = "Validation accuracy")
plt.legend()
plt.title("SGD, BN LR = 1e-4, [3, 16, 32, 48]")
plt.savefig("Images/16")
