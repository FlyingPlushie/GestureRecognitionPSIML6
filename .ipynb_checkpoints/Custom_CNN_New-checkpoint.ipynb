# %%
import time
import os
import copy
from collections import defaultdict

# deep learning/vision libraries
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
from torchvision import datasets, models, transforms
import cv2 as cv  # OpenCV

# numeric and plotting libraries
import numpy as np
import matplotlib.pyplot as plt
from kard_data_loader import KardDataLoader
import consts as c

# %%
train = KardDataLoader('C:\\Users\\bozam\\Desktop\\KARD train test validation\\train\\')
train.getActivityData(c.FILETYPES['screen'])

# %%
test = KardDataLoader('C:\\Users\\bozam\\Desktop\\KARD train test validation\\test\\')
test.getActivityData(c.FILETYPES['screen'])

# %%
validation = KardDataLoader('C:\\Users\\bozam\\Desktop\\KARD train test validation\\validation\\')
validation.getActivityData(c.FILETYPES['screen'])

# %%
def normalize(arr):
    return (arr - np.min(arr)) / (np.max(arr) - np.min(arr))

# %%
def make_training_set(data):
    generated_images = []
    generated_classes = []
    x = []
    y = []
    z = []
            
    for class_name in range(len(data)):
        image_sequence = []
        for people_sequences in range(len(data[class_name])):
            counter = 0
            for people_coordinates in data[class_name][people_sequences]:
                x.append(people_coordinates[0])
                y.append(people_coordinates[1])
                z.append(people_coordinates[2])
                counter += 1
                
                if counter == 15:
                    counter = 0
                    x = normalize(x)
                    
                    y = normalize(y)
                    
                    z = normalize(z)
                    
                    image_layer = [[x[i], y[i], z[i]] for i in range(15)]
                    generated_images.append(image_layer)
                    generated_classes.append(class_name)
                    x = []
                    y = []
                    z = []
            
    return generated_images, generated_classes

# %%
train_images, train_labels = make_training_set(train.data)
train_images = np.array(train_images)
train_labels = np.array(train_labels)

# %%
validation_images, validation_labels = make_training_set(validation.data)
validation_images = np.array(validation_images)
validation_labels = np.array(validation_labels)

# %%
test_images, test_labels = make_training_set(test.data)
test_images = np.array(test_images)
test_labels = np.array(test_labels)

# %%
def to_categorical(y, num_classes):
    return np.eye(num_classes, dtype='uint8')[y]

# %%
def make_images_compact(train_data, train_labels, batch_size, stride):
    batch_edges = [[a, a + batch_size] for a in range(0 , len(train_data) - batch_size, stride) if train_labels[a] == train_labels[a + batch_size]]
    
    batch_data = []
    batch_labels = []
    
    for (a, b) in (batch_edges):
        batch_data.append(train_data[a:b])
        batch_labels.append(train_labels[a])
    
    rnd_idx = np.random.permutation(len(batch_data))
    batch_data = np.array(batch_data)
    batch_labels = np.array(batch_labels)
    
    batch_data = batch_data[rnd_idx, :, :, :]
    batch_labels = batch_labels[rnd_idx]
    
    return (batch_data, batch_labels)

# %%
def make_batches(X_train, y_train, batch_size):
    n_batches = len(X_train) // batch_size
    indexes = np.array(list(range(0, len(X_train))))
    for batch_idx in np.array_split(indexes, n_batches):
        X_batch, y_batch = X_train[batch_idx], y_train[batch_idx]
        yield X_batch, y_batch

# %%
train_images_new, train_labels_new = make_images_compact(train_images, train_labels, 40, 3)

# %%
validation_images_new, validation_labels_new = make_images_compact(validation_images, validation_labels, 40, 3)

# %%
test_images_new, test_labels_new = make_images_compact(test_images, test_labels, 40, 3)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %%
def train_model(model, criterion, optimizer, num_epochs=100):
    
    metrics = defaultdict(list)
    best_acc = 0
    
    for epoch in range(num_epochs):
        print(f'Epoch {epoch}/{num_epochs - 1}')
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', "val"]:
            if phase == 'train':
                model.train()  # Set model to training mode
                data = train_images_new
                labels = train_labels_new
            else:
                model.eval()   # Set model to evaluate mode
                data = validation_images_new
                labels = validation_labels_new
                
            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            # 40, 15, 3 - > 3, 15, 40
            #print(np.array(train_images).shape)
            #print(np.array(train_labels).shape)
            for (inputs, labels) in make_batches(data, labels, 40):
                #print(np.array(inputs).shape)
                #inputs = inputs.reshape(3, 15, 41)
                inputs = inputs.reshape(-1, 3, 15, 40)
                inputs = torch.from_numpy(inputs)
                labels = torch.from_numpy(np.array([labels]))
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()
                
                # forward
                # track history if only in train
                #print("Pre setovanja gradienata!")
                with torch.set_grad_enabled(phase == 'train'):
                    #print("Ulazim u setovanje gradienata!!!!")
                    outputs = model(inputs.float())
                    
                    _, preds = torch.max(outputs, 1)
                    labels = labels.view(-1)
                    loss = criterion(outputs, labels.long())
                    #print(loss)
                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data).item()
            
            epoch_loss = running_loss / len(data)
            epoch_acc = float(running_corrects) / len(data)

            print(f'{phase} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())
            
            metrics[phase+"_loss"].append(epoch_loss)
            metrics[phase+"_acc"].append(epoch_acc)

    return metrics

# %%
class CustomCNN(nn.Module):
    # [50, 100, 3, 3], but got 3-dimensional input of size [40, 15, 3]
    def __init__(self):
        super().__init__()
        
        num_of_channels = [3, 16, 32, 64, 128]
        kernel_sizes = [3, 3, 3, 3]
        stride_sizes = [2, 2, 2, 2]
        
        self.relu = torch.nn.ReLU()
        
        self.conv1 = nn.Conv2d(num_of_channels[0], num_of_channels[1], kernel_size=(4, 1), stride=stride_sizes[0])
        self.conv2 = nn.Conv2d(num_of_channels[1], num_of_channels[2], kernel_size=(2, 9), stride=stride_sizes[1])
        self.conv3 = nn.Conv2d(num_of_channels[2], num_of_channels[3], kernel_size=(1, 2), stride=stride_sizes[2])
        self.conv4 = nn.Conv2d(num_of_channels[3], num_of_channels[4], kernel_size=(2, 3), stride=stride_sizes[3])
        self.avgpool = nn.AdaptiveAvgPool2d((7, 7))
        self.classifier = nn.Linear(num_of_channels[-1] * 7 * 7, 18)
        
        
    def forward(self, x):
        y = self.relu(self.conv1(x))
        y = self.relu(self.conv2(y))
        y = self.relu(self.conv3(y))
        y = self.relu(self.conv4(y))
        y = self.avgpool(y)
        y = torch.flatten(y, 1)
        y = self.classifier(y)
        
        return y
    
    
custom_cnn = CustomCNN().to(device)
optimizer_conv = optim.Adam(filter(lambda p: p.requires_grad, custom_cnn.parameters()))

print(f"number of params in model {count_parameters(custom_cnn)}")

criterion = nn.CrossEntropyLoss()
metrics = train_model(custom_cnn, criterion, optimizer_conv, num_epochs=100)
# Out:
# number of params in model 175810
# Epoch 0/99
# ----------
# train Loss: 1.1940 Acc: 0.5964
# val Loss: 0.5655 Acc: 0.7753
# Epoch 1/99
# ----------
# train Loss: 0.5337 Acc: 0.8162
# val Loss: 0.5919 Acc: 0.7874
# Epoch 2/99
# ----------
# train Loss: 0.3701 Acc: 0.8681
# val Loss: 0.6134 Acc: 0.7854
# Epoch 3/99
# ----------
# train Loss: 0.2833 Acc: 0.9008
# val Loss: 0.5362 Acc: 0.8219
# Epoch 4/99
# ----------
# train Loss: 0.2228 Acc: 0.9191
# val Loss: 0.6669 Acc: 0.8077
# Epoch 5/99
# ----------
# train Loss: 0.1759 Acc: 0.9358
# val Loss: 0.6445 Acc: 0.8057
# Epoch 6/99
# ----------
# train Loss: 0.1449 Acc: 0.9471
# val Loss: 0.5595 Acc: 0.8097
# Epoch 7/99
# ----------
# train Loss: 0.1271 Acc: 0.9531
# val Loss: 0.3889 Acc: 0.8563
# Epoch 8/99
# ----------
# train Loss: 0.1193 Acc: 0.9548
# val Loss: 0.5767 Acc: 0.8502
# Epoch 9/99
# ----------
# train Loss: 0.1100 Acc: 0.9591
# val Loss: 0.6356 Acc: 0.8603
# Epoch 10/99
# ----------
# train Loss: 0.0978 Acc: 0.9638
# val Loss: 0.7279 Acc: 0.8259
# Epoch 11/99
# ----------
# train Loss: 0.0916 Acc: 0.9670
# val Loss: 0.6411 Acc: 0.8320
# Epoch 12/99
# ----------
# train Loss: 0.0899 Acc: 0.9677
# val Loss: 0.6973 Acc: 0.8482
# Epoch 13/99
# ----------
# train Loss: 0.0862 Acc: 0.9690
# val Loss: 1.0336 Acc: 0.8178
# Epoch 14/99
# ----------
# train Loss: 0.0761 Acc: 0.9715
# val Loss: 1.4222 Acc: 0.7692
# Epoch 15/99
# ----------
# train Loss: 0.0740 Acc: 0.9746
# val Loss: 1.0085 Acc: 0.8300
# Epoch 16/99
# ----------
# train Loss: 0.0655 Acc: 0.9767
# val Loss: 1.2725 Acc: 0.8259
# Epoch 17/99
# ----------
# train Loss: 0.0696 Acc: 0.9754
# val Loss: 0.9437 Acc: 0.8482
# Epoch 18/99
# ----------
# train Loss: 0.0643 Acc: 0.9779
# val Loss: 1.0676 Acc: 0.8239
# Epoch 19/99
# ----------
# train Loss: 0.0689 Acc: 0.9764
# val Loss: 1.1523 Acc: 0.8097
# Epoch 20/99
# ----------
# train Loss: 0.0534 Acc: 0.9824
# val Loss: 0.9790 Acc: 0.8097
# Epoch 21/99
# ----------
# train Loss: 0.0655 Acc: 0.9781
# val Loss: 1.0600 Acc: 0.8381
# Epoch 22/99
# ----------
# train Loss: 0.0577 Acc: 0.9809
# val Loss: 1.2456 Acc: 0.8381
# Epoch 23/99
# ----------
# train Loss: 0.0500 Acc: 0.9826
# val Loss: 1.6846 Acc: 0.7915
# Epoch 24/99
# ----------
# train Loss: 0.0586 Acc: 0.9810
# val Loss: 1.1070 Acc: 0.8320
# Epoch 25/99
# ----------
# train Loss: 0.0535 Acc: 0.9815
# val Loss: 1.3308 Acc: 0.8117
# Epoch 26/99
# ----------
# train Loss: 0.0423 Acc: 0.9863
# val Loss: 1.1326 Acc: 0.8340
# Epoch 27/99
# ----------
# train Loss: 0.0668 Acc: 0.9794
# val Loss: 0.8766 Acc: 0.8644
# Epoch 28/99
# ----------
# train Loss: 0.0512 Acc: 0.9838
# val Loss: 1.0031 Acc: 0.8522
# Epoch 29/99
# ----------
# train Loss: 0.0513 Acc: 0.9839
# val Loss: 1.3984 Acc: 0.7935
# Epoch 30/99
# ----------
# train Loss: 0.0512 Acc: 0.9830
# val Loss: 0.8707 Acc: 0.8785
# Epoch 31/99
# ----------
# train Loss: 0.0383 Acc: 0.9879
# val Loss: 1.2722 Acc: 0.8320
# Epoch 32/99
# ----------
# train Loss: 0.0592 Acc: 0.9822
# val Loss: 0.9795 Acc: 0.8462
# Epoch 33/99
# ----------
# train Loss: 0.0593 Acc: 0.9824
# val Loss: 1.2729 Acc: 0.8522
# Epoch 34/99
# ----------
# train Loss: 0.0478 Acc: 0.9847
# val Loss: 1.4776 Acc: 0.8178
# Epoch 35/99
# ----------
# train Loss: 0.0469 Acc: 0.9857
# val Loss: 1.1430 Acc: 0.8381
# Epoch 36/99
# ----------
# train Loss: 0.0457 Acc: 0.9863
# val Loss: 1.4383 Acc: 0.7874
# Epoch 37/99
# ----------
# train Loss: 0.0473 Acc: 0.9853
# val Loss: 1.5577 Acc: 0.8259
# Epoch 38/99
# ----------
# train Loss: 0.0331 Acc: 0.9894
# val Loss: 1.0701 Acc: 0.8563
# Epoch 39/99
# ----------
# train Loss: 0.0490 Acc: 0.9851
# val Loss: 1.1737 Acc: 0.8259
# Epoch 40/99
# ----------
# train Loss: 0.0500 Acc: 0.9851
# val Loss: 0.9696 Acc: 0.8745
# Epoch 41/99
# ----------
# train Loss: 0.0490 Acc: 0.9860
# val Loss: 1.0505 Acc: 0.8745
# Epoch 42/99
# ----------
# train Loss: 0.0427 Acc: 0.9875
# val Loss: 1.5419 Acc: 0.7915
# Epoch 43/99
# ----------
# train Loss: 0.0633 Acc: 0.9822
# val Loss: 1.5022 Acc: 0.8198
# Epoch 44/99
# ----------
# train Loss: 0.0352 Acc: 0.9885
# val Loss: 1.5129 Acc: 0.8340
# Epoch 45/99
# ----------
# train Loss: 0.0250 Acc: 0.9916
# val Loss: 1.8394 Acc: 0.8482
# Epoch 46/99
# ----------
# train Loss: 0.0540 Acc: 0.9854
# val Loss: 1.0436 Acc: 0.8563
# Epoch 47/99
# ----------
# train Loss: 0.0383 Acc: 0.9890
# val Loss: 1.1385 Acc: 0.8583
# Epoch 48/99
# ----------
# train Loss: 0.0402 Acc: 0.9885
# val Loss: 1.6704 Acc: 0.8259
# Epoch 49/99
# ----------
# train Loss: 0.0454 Acc: 0.9869
# val Loss: 1.3855 Acc: 0.8583
# Epoch 50/99
# ----------
# train Loss: 0.0249 Acc: 0.9925
# val Loss: 0.6808 Acc: 0.8947
# Epoch 51/99
# ----------
# train Loss: 0.0803 Acc: 0.9786
# val Loss: 1.8196 Acc: 0.8421
# Epoch 52/99
# ----------
# train Loss: 0.0401 Acc: 0.9897
# val Loss: 1.3217 Acc: 0.8543
# Epoch 53/99
# ----------
# train Loss: 0.0362 Acc: 0.9907
# val Loss: 1.3705 Acc: 0.8684
# Epoch 54/99
# ----------
# train Loss: 0.0262 Acc: 0.9923
# val Loss: 1.1171 Acc: 0.8846
# Epoch 55/99
# ----------
# train Loss: 0.0528 Acc: 0.9856
# val Loss: 1.4685 Acc: 0.8381
# Epoch 56/99
# ----------
# train Loss: 0.0524 Acc: 0.9877
# val Loss: 1.6173 Acc: 0.8320
# Epoch 57/99
# ----------
# train Loss: 0.0385 Acc: 0.9892
# val Loss: 1.7988 Acc: 0.8401
# Epoch 58/99
# ----------
# train Loss: 0.0486 Acc: 0.9878
# val Loss: 1.3665 Acc: 0.8543
# Epoch 59/99
# ----------
# train Loss: 0.0218 Acc: 0.9935
# val Loss: 1.4511 Acc: 0.8563
# Epoch 60/99
# ----------
# train Loss: 0.0612 Acc: 0.9847
# val Loss: 1.2988 Acc: 0.8543
# Epoch 61/99
# ----------
# train Loss: 0.0332 Acc: 0.9913
# val Loss: 1.8119 Acc: 0.8300
# Epoch 62/99
# ----------
# train Loss: 0.0391 Acc: 0.9897
# val Loss: 1.3284 Acc: 0.8482
# Epoch 63/99
# ----------
# train Loss: 0.0317 Acc: 0.9915
# val Loss: 1.4494 Acc: 0.8421
# Epoch 64/99
# ----------
# train Loss: 0.0654 Acc: 0.9861
# val Loss: 1.5396 Acc: 0.8543
# Epoch 65/99
# ----------
# train Loss: 0.0295 Acc: 0.9928
# val Loss: 1.5059 Acc: 0.8623
# Epoch 66/99
# ----------
# train Loss: 0.0417 Acc: 0.9893
# val Loss: 1.5956 Acc: 0.8563
# Epoch 67/99
# ----------
# train Loss: 0.0432 Acc: 0.9904
# val Loss: 1.7282 Acc: 0.8259
# Epoch 68/99
# ----------
# train Loss: 0.0403 Acc: 0.9902
# val Loss: 1.2146 Acc: 0.8846
# Epoch 69/99
# ----------
# train Loss: 0.0378 Acc: 0.9909
# val Loss: 1.5548 Acc: 0.8684
# Epoch 70/99
# ----------
# train Loss: 0.0351 Acc: 0.9911
# val Loss: 2.1459 Acc: 0.8219
# Epoch 71/99
# ----------
# train Loss: 0.0371 Acc: 0.9908
# val Loss: 2.0872 Acc: 0.8340
# Epoch 72/99
# ----------
# train Loss: 0.0557 Acc: 0.9866
# val Loss: 1.5704 Acc: 0.8623
# Epoch 73/99
# ----------
# train Loss: 0.0439 Acc: 0.9896
# val Loss: 1.4318 Acc: 0.8988
# Epoch 74/99
# ----------
# train Loss: 0.0301 Acc: 0.9925
# val Loss: 1.1078 Acc: 0.8704
# Epoch 75/99
# ----------
# train Loss: 0.0246 Acc: 0.9935
# val Loss: 1.8735 Acc: 0.8462
# Epoch 76/99
# ----------
# train Loss: 0.0512 Acc: 0.9886
# val Loss: 1.4648 Acc: 0.8603
# Epoch 77/99
# ----------
# train Loss: 0.0538 Acc: 0.9888
# val Loss: 1.3021 Acc: 0.8543
# Epoch 78/99
# ----------
# train Loss: 0.0504 Acc: 0.9898
# val Loss: 2.3378 Acc: 0.8300
# Epoch 79/99
# ----------
# train Loss: 0.0426 Acc: 0.9907
# val Loss: 1.3843 Acc: 0.8603
# Epoch 80/99
# ----------
# train Loss: 0.0169 Acc: 0.9957
# val Loss: 1.4154 Acc: 0.8765
# Epoch 81/99
# ----------
# train Loss: 0.0586 Acc: 0.9878
# val Loss: 2.0731 Acc: 0.8462
# Epoch 82/99
# ----------
# train Loss: 0.0497 Acc: 0.9904
# val Loss: 1.3421 Acc: 0.8866
# Epoch 83/99
# ----------
# train Loss: 0.0284 Acc: 0.9931
# val Loss: 1.6383 Acc: 0.8988
# Epoch 84/99
# ----------
# train Loss: 0.0769 Acc: 0.9860
# val Loss: 2.0553 Acc: 0.8441
# Epoch 85/99
# ----------
# train Loss: 0.0230 Acc: 0.9943
# val Loss: 1.2707 Acc: 0.8887
# Epoch 86/99
# ----------
# train Loss: 0.0317 Acc: 0.9933
# val Loss: 1.3706 Acc: 0.9008
# Epoch 87/99
# ----------
# train Loss: 0.0786 Acc: 0.9859
# val Loss: 1.5661 Acc: 0.8785
# Epoch 88/99
# ----------
# train Loss: 0.0393 Acc: 0.9922
# val Loss: 1.6879 Acc: 0.8927
# Epoch 89/99
# ----------
# train Loss: 0.0311 Acc: 0.9931
# val Loss: 1.3566 Acc: 0.9008
# Epoch 90/99
# ----------
# train Loss: 0.0534 Acc: 0.9902
# val Loss: 2.2321 Acc: 0.8502
# Epoch 91/99
# ----------
# train Loss: 0.0473 Acc: 0.9905
# val Loss: 1.6098 Acc: 0.8704
# Epoch 92/99
# ----------
# train Loss: 0.0358 Acc: 0.9925
# val Loss: 2.4043 Acc: 0.8462
# Epoch 93/99
# ----------
# train Loss: 0.0554 Acc: 0.9911
# val Loss: 2.8191 Acc: 0.8016
# Epoch 94/99
# ----------
# train Loss: 0.0484 Acc: 0.9892
# val Loss: 1.5026 Acc: 0.8826
# Epoch 95/99
# ----------
# train Loss: 0.0272 Acc: 0.9936
# val Loss: 1.2456 Acc: 0.8826
# Epoch 96/99
# ----------
# train Loss: 0.0160 Acc: 0.9962
# val Loss: 2.2704 Acc: 0.8563
# Epoch 97/99
# ----------
# train Loss: 0.0549 Acc: 0.9882
# val Loss: 1.5415 Acc: 0.8927
# Epoch 98/99
# ----------
# train Loss: 0.0400 Acc: 0.9920
# val Loss: 1.4078 Acc: 0.8968
# Epoch 99/99
# ----------
# train Loss: 0.0256 Acc: 0.9948
# val Loss: 2.0501 Acc: 0.8421

# %%
plt.plot(list(range(0, len(metrics["train_loss"]))), metrics["train_loss"])
plt.plot(list(range(0, len(metrics["val_loss"]))), metrics["val_loss"])
plt.show()

# %%
plt.plot(list(range(0, len(metrics["train_loss"]))), metrics["train_loss"], label = "Train loss")
plt.plot(list(range(0, len(metrics["val_loss"]))), metrics["val_loss"], label = "Val loss")
plt.legend()
plt.title("No batch normalizaion")
plt.savefig("Images/1")

# %%
plt.plot(list(range(0, len(metrics["train_acc"]))), metrics["train_acc"], label = "Train accuracy")
plt.plot(list(range(0, len(metrics["val_acc"]))), metrics["val_acc"], label = "Validation accuracy")
plt.legend()
plt.title("No batch normalizaion")
plt.savefig("Images/2")
